# %% [markdown]
# # Reconocimiento de patrones: Identificación de grupos o Clustering
# ### Ramón Soto C. [(rsotoc@moviquest.com)](mailto:rsotoc@moviquest.com/)
# ![ ](images/blank.png)
# ![agents](images/binary_data_under_a_magnifying.jpg)
# [ver en nbviewer](http://nbviewer.ipython.org/github/rsotoc/pattern-recognition/blob/master/Clustering%20III.ipynb)

# %% [markdown]
# ## Técnicas de clustering: *K-Means*
#
# La técnica de *k-medias* (o *k-means*) es una de las técnicas de clustering más simples y más utilizadas. Es una técnica de *aprendizaje no supervisado*: la técnica debe clasificar objetos desconocidos a un conjunto de clases de las que apenas se conocen algunos parámetros y no las características de cada clase. En el caso de *k*-medias, lo único que se conoce es el número de grupos.
#
# El objetivo del algoritmo de *k*-medias es particionar un conjunto de *n* datos ejemplo en *k* grupos, asociando objetos cercanos y distinguiendo objetos diferentes. El resultado al final del procedimiento es la generación de un "*prototipo de clase*".
#
# En la imagen a continuación, se presentan 30 datos (puntos azules) que han sido agrupados en 4 clusters. Las líneas rojas representan fronteras (posibles) entre clase y las estrellas rojas representan prototipos de clase.
#
# ![ ](images/k-means0.png)
#
# La clase es una generalización del cluster; una descripción conceptual del grupo representado por el conjunto de datos. La delimitación de una clase, construida de forma inductiva (a partir de ejemplos), suele no ser precisa: está limitada a los datos de que disponemos para modelarla, como se ilustra en la imagen siguiente.
#
# ![ ](images/cluster-class.png)
#
# En esta imagen, los datos (ficticios) conocidos nos han permitido generar un modelo de clase (area en azul). Sin embargo, la clase real es diferente, sólo que al crear la clase no conocíamos suficientes datos para modelarla fielmente (como los datos señalados como puntos rojos). Considérese, por ejemplo, el siguiente conjunto de bicicletas:
#
# ![ ](images/bicycles.png)
#
# A partir de los datos disponibles podemos concluir, por ejemplo, que todas las bicicletas tienen un asiento y pedales... sin embargo, esta definción de la clase bicicleta no incluye los siguientes ejemplares:
#
# [![ ](images/bicycles-2.png)](https://www.youtube.com/watch?v=KewMZ8sM0Uo)

# %% [markdown]
# ### Algoritmo
#
# El algoritmo k-means sigue los siguientes pasos:
#
# 1. Definir el valor de  $k$
# 2. Seleccionar de manera arbitraria k puntos en el espacio de características como centros iniciales de los clusters.
# 3. Asignar cada punto del conjunto de datos al cluster donde la distancia del punto al centroide es menor.
# 4. Volver a calcular los centroides a partir de los puntos en cada cluster.
# 5. Repetir los pasos 3 y 4 hasta que no haya cambios en los clusters.

# %%
# Inicializar el ambiente
import numpy as np
import pandas as pd
import math
import random
import time
import os
import sys
from IPython.display import display, HTML

from scipy.spatial import distance
np.set_printoptions(precision=2, suppress=True) # Cortar la impresión de decimales a 1

os.chdir('Data sets')
LARGER_DISTANCE = sys.maxsize
TALK = True # TALK = True, imprime resultados parciales

# %%
# Leer los datos de archivo
DATA_SET = pd.read_csv("datosProm.csv", names = ['A', 'B']).values
DATA_LEN = len(DATA_SET)

# Definir una clase para expresar puntos y su asignación a un cluster
class DataPoint:
    # Constructor
    def __init__(self, p):
        self.value = p
        
    def set_value(self, p):
        self.value = p
    
    def get_value(self):
        return self.value
    
    def set_cluster(self, cluster):
        self.cluster = cluster
    
    def get_cluster(self):
        return self.cluster

data = []
def initialize_dataset(printing):
    string = ""
    for i in range(DATA_LEN):
        point = DataPoint(DATA_SET[i])
        point.set_cluster(None)
        data.append(point)
        
        if printing:
            string = string + "<tr><th>"+str(point.get_value()) 
            string = string + "</th> <th>"+str(point.get_cluster())+"</th></tr>"

    if printing:
        display(HTML("<table>" + string + "</table>"))

    return

# --------------------------
# Crear el conjunto de datos
initialize_dataset(True)
# Out:
# <table><tr><th>[ 70.28  42.12]</th> <th>None</th></tr><tr><th>[  0.    56.75]</th> <th>None</th></tr><tr><th>[ 79.    2.5]</th> <th>None</th></tr><tr><th>[ 75.64  11.67]</th> <th>None</th></tr><tr><th>[ 82.   58.8]</th> <th>None</th></tr><tr><th>[ 86.    77.27]</th> <th>None</th></tr><tr><th>[ 80.   85.5]</th> <th>None</th></tr><tr><th>[ 68.2   62.44]</th> <th>None</th></tr><tr><th>[ 72.  88.]</th> <th>None</th></tr><tr><th>[ 74.   80.6]</th> <th>None</th></tr><tr><th>[ 91.72   0.  ]</th> <th>None</th></tr><tr><th>[ 77.69  13.17]</th> <th>None</th></tr><tr><th>[ 79.8  71.2]</th> <th>None</th></tr><tr><th>[ 87.1   75.39]</th> <th>None</th></tr><tr><th>[  0.    80.85]</th> <th>None</th></tr><tr><th>[  0.    59.93]</th> <th>None</th></tr><tr><th>[ 96.   5.]</th> <th>None</th></tr><tr><th>[ 86.    89.58]</th> <th>None</th></tr><tr><th>[  0.    76.25]</th> <th>None</th></tr><tr><th>[  0.    90.62]</th> <th>None</th></tr><tr><th>[ 100.     95.06]</th> <th>None</th></tr><tr><th>[ 87.    62.56]</th> <th>None</th></tr><tr><th>[ 79.    82.46]</th> <th>None</th></tr><tr><th>[  0.    75.92]</th> <th>None</th></tr><tr><th>[  0.    76.88]</th> <th>None</th></tr><tr><th>[ 73.46  83.53]</th> <th>None</th></tr><tr><th>[ 92.    87.56]</th> <th>None</th></tr><tr><th>[ 77.    84.38]</th> <th>None</th></tr><tr><th>[ 70.8  35. ]</th> <th>None</th></tr><tr><th>[ 92.6   66.88]</th> <th>None</th></tr></table>

# %% [markdown]
# 1) Definir el valor de $k$

# %%
NUM_CLUSTERS = 3

# %% [markdown]
# 2) Seleccionar de manera arbitraria *k* puntos en el espacio de características como centros iniciales de  los clusters (centroides o centros de masa).
# ![ ](images/k-means1.png)

# %%
# Definir forma de muestreo; 0 = random, 1=head, 2=tail
SAMPLING_METHOD = 1 

centroids = []
def initialize_centroids():
    if (TALK) : 
        print("Centroides inicializados en:")
    for c in range(NUM_CLUSTERS):
        if (SAMPLING_METHOD == 0) :
            which = random.randint(0,DATA_LEN-1)
        elif (SAMPLING_METHOD == 1):
            which = c
        else :
            which = DATA_LEN-1 - c
                
        centroids.append(list(DATA_SET[which]))
        if (TALK) : 
            print(centroids[c])      
            
    if (TALK) : 
        print()
    
    return

# --------------------------
# Inicializar los centroides
initialize_centroids()
# Out:
# Centroides inicializados en:
# [70.280000000000001, 42.125]
# [0.0, 56.75]
# [79.0, 2.5]

# %% [markdown]
# 3) Asignar cada punto del conjunto de datos al cluster donde la distancia del punto al centroide es menor.
# ![ ](images/k-means2.png)

# %%
def update_clusters():
    changed = False
    
    for i in range(DATA_LEN):
        minDistance = LARGER_DISTANCE
        currentCluster = 0
        
        # Buscar la menor distancia del punto p_i a un centroide
        for j in range(NUM_CLUSTERS):
            dist = distance.euclidean(data[i].get_value(), centroids[j])
            if(dist < minDistance):
                minDistance = dist
                currentCluster = j
        
        # Si hay cambi, realizarlo y levantar la bandera 'changed'
        if(data[i].get_cluster() is None or data[i].get_cluster() != currentCluster):
            data[i].set_cluster(currentCluster)
            changed = True
            
    # Contabilizar los elementos en cada cluster
    members = [0] * NUM_CLUSTERS
    for i in range(DATA_LEN):
        members[data[i].get_cluster()] += 1
    
    if (TALK) : 
        for j in range(NUM_CLUSTERS):
            print("El cluster ", j, " incluye ", members[j], "miembros.")
        print()
            
    return changed

# --------------------------
# Actualizar los clusters
KEEP_WALKING = update_clusters()
# Out:
# El cluster  0  incluye  18 miembros.
# El cluster  1  incluye  7 miembros.
# El cluster  2  incluye  5 miembros.

# %% [markdown]
# 4) Calcular los centroides a partir de los puntos en cada cluster.
# ![ ](images/k-means3.png)

# %%
def update_centroids():    
    if (TALK) : 
        print("Los nuevos centroids son:")
    for j in range(NUM_CLUSTERS):
        means = [0] * DATA_SET.shape[1]
            
        clusterSize = 0
        for k in range(len(data)):
            if(data[k].get_cluster() == j):
                p = data[k].get_value()
                for i in range(DATA_SET.shape[1]):
                    means[i] += p[i]
                clusterSize += 1

        if(clusterSize > 0):
            for i in range(DATA_SET.shape[1]):
                centroids[j][i] = means[i] / clusterSize

        if (TALK) : 
            print(centroids[j])        
    if (TALK) : 
        print()
    
    return

# --------------------------
# Actualizar los centroides
update_centroids()
# Out:
# Los nuevos centroids son:
# [80.957777777777778, 73.79605555555554]
# [0.0, 73.886571428571415]
# [84.009999999999991, 6.466800000000001]

# %% [markdown]
# 5) Repetir los pasos 2 y 3 hasta que no haya cambios en los clusters.
# ![ ](images/k-means4.png)

# %%
while(KEEP_WALKING):
    KEEP_WALKING = update_clusters()
    if (KEEP_WALKING):
        update_centroids()
    else :
        if (TALK) : 
            print ("No más cambios.")
# Out:
# El cluster  0  incluye  17 miembros.
# El cluster  1  incluye  7 miembros.
# El cluster  2  incluye  6 miembros.
#
# Los nuevos centroids son:
# [81.555294117647065, 76.078176470588218]
# [0.0, 73.886571428571415]
# [81.808333333333323, 11.222333333333333]
#
# El cluster  0  incluye  16 miembros.
# El cluster  1  incluye  7 miembros.
# El cluster  2  incluye  7 miembros.
#
# Los nuevos centroids son:
# [82.259999999999991, 78.200249999999983]
# [0.0, 73.886571428571415]
# [80.161428571428573, 15.637]
#
# El cluster  0  incluye  16 miembros.
# El cluster  1  incluye  7 miembros.
# El cluster  2  incluye  7 miembros.
#
# No más cambios.

# %% [markdown]
# <hr style="border-width: 1px;">
#
# El método $k$-means es un método muy robusto. Su principal restricción es la selección adecuada del número de clusters, $k$. En casos más interesantes que nuestro ejemplo, conviene realizar un análisis previo de determinación de clusters, por dendrogramas, por ejemplo.
#
# En el caso de los datos del *Pima Indian Diabetes Data Set*, por ejemplo, el análisis por dendrogramas ha arrojado:

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
# %matplotlib inline

df = pd.read_csv("Pima Indian Data Set/pima-indians-diabetes.data", 
                 names = ['emb', 'gl2h', 'pad', 'ept', 'is2h', 'imc', 'fpd', 'edad', 'class'])
df.loc[df['pad'] == 0,'pad'] = np.nan
df.loc[df['ept'] == 0,'ept'] = np.nan
df.loc[df['is2h'] == 0,'is2h'] = np.nan
df.loc[df['imc'] == 0,'imc'] = np.nan
df = df.dropna()
print(df.describe())

Z = linkage(df, 'centroid')
plt.figure(figsize=(12, 5))
dendrogram(Z, truncate_mode='lastp', p=4, show_leaf_counts=True, leaf_font_size=14.)
plt.show()
# Out:
#               emb        gl2h         pad         ept        is2h         imc  \
# count  393.000000  393.000000  393.000000  393.000000  393.000000  393.000000
# mean     3.295165  122.315522   70.671756   29.122137  155.717557   33.072519
# std      3.209425   31.435992   12.481277   10.513128  118.879630    7.023947
# min      0.000000    0.000000   24.000000    7.000000   14.000000   18.200000
# 25%      1.000000   99.000000   62.000000   21.000000   76.000000   28.400000
# 50%      2.000000  119.000000   70.000000   29.000000  125.000000   33.200000
# 75%      5.000000  143.000000   78.000000   37.000000  190.000000   37.100000
# max     17.000000  198.000000  110.000000   63.000000  846.000000   67.100000
#
#               fpd        edad       class
# count  393.000000  393.000000  393.000000
# mean     0.522476   30.839695    0.330789
# std      0.345232   10.199903    0.471097
# min      0.085000   21.000000    0.000000
# 25%      0.270000   23.000000    0.000000
# 50%      0.447000   27.000000    0.000000
# 75%      0.687000   36.000000    1.000000
# max      2.420000   81.000000    1.000000

# %% [markdown]
# Nótese que en este caso hemos desechado los datos incompletos.
#
# Podemos tomar este dendrograma y probar suerte con $k=4$:

# %%
NUM_CLUSTERS = 4
TALK = False
DATA_SET = df.values
DATA_LEN = len(DATA_SET)
SAMPLING_METHOD = 0 

data = []
initialize_dataset(False)
centroids = []
initialize_centroids()

KEEP_WALKING = True
while(KEEP_WALKING):
    KEEP_WALKING = update_clusters()
    if (KEEP_WALKING):
        update_centroids()
    else :
        members = [0] * NUM_CLUSTERS
        for i in range(DATA_LEN):
            members[data[i].get_cluster()] += 1

        for j in range(NUM_CLUSTERS):
            print("\nCluster {}: {} miembros.".format(j, members[j]))
            print(np.asarray(centroids[j]))
# Out:
# Cluster 0: 143 miembros.
# [   3.89  133.31   71.69   30.71  160.43   34.11    0.54   33.29    0.5 ]
#
# Cluster 1: 18 miembros.
# [   3.11  165.83   73.44   35.67  548.83   36.96    0.66   34.56    0.67]
#
# Cluster 2: 52 miembros.
# [   4.25  149.62   74.04   30.87  291.48   35.58    0.56   33.9     0.5 ]
#
# Cluster 3: 180 miembros.
# [   2.57  101.34   68.62   26.7    73.44   31.14    0.48   27.64    0.12]

# %% [markdown]
# Y comparando con los resultados obtenido con sklearn.cluster.KMeans

# %%
from sklearn import cluster
k_means = cluster.KMeans(n_clusters=4, init='random')
k_means.fit(df) 

print(k_means.cluster_centers_)
# Out:
# [[   4.25  149.62   74.04   30.87  291.48   35.58    0.56   33.9     0.5 ]
#  [   2.57  101.34   68.62   26.7    73.44   31.14    0.48   27.64    0.12]
#  [   3.11  165.83   73.44   35.67  548.83   36.96    0.66   34.56    0.67]
#  [   3.89  133.31   71.69   30.71  160.43   34.11    0.54   33.29    0.5 ]]

# %% [markdown]
# <hr style="border-width: 3px;">
#
# ### Magic
#
# A continuación se realiza un análisis de cartas del juego *Magic The Gathering*. Este problema es difícil porque muchos datos son categóricos.

# %%
import numpy as np 
import pandas as pd 
import pprint
pd.options.display.max_columns = 199

#Lectura de datos en bruto
raw = pd.read_json("Magic/AllSets-x.json")
display(raw.info())
display(raw)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, block to type
# Columns: 199 entries, LEA to MPS
# dtypes: object(199)
# memory usage: 25.0+ KB
# None
#                                                                   LEA  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Richard Thomas', 'cmc': 5, 'color...
# code                                                              LEA
# gathererCode                                                       1E
# magicCardsInfoCode                                                 al
# magicRaritiesCodes                                                NaN
# mkm_id                                                              1
# mkm_name                                                        Alpha
# name                                            Limited Edition Alpha
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1993-08-05
# translations                                                      NaN
# type                                                             core
#
#                                                                   LEB  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Richard Thomas', 'cmc': 5, 'color...
# code                                                              LEB
# gathererCode                                                       2E
# magicCardsInfoCode                                                 be
# magicRaritiesCodes                                                NaN
# mkm_id                                                              2
# mkm_name                                                         Beta
# name                                             Limited Edition Beta
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1993-10-01
# translations                                                      NaN
# type                                                             core
#
#                                                                   ARN  \
# block                                                             NaN
# booster             [uncommon, uncommon, common, common, common, c...
# border                                                          black
# cards               [{'artist': 'Ken Meyer, Jr.', 'cmc': 1, 'color...
# code                                                              ARN
# gathererCode                                                       AN
# magicCardsInfoCode                                                 an
# magicRaritiesCodes                                                NaN
# mkm_id                                                              4
# mkm_name                                               Arabian Nights
# name                                                   Arabian Nights
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1993-12-01
# translations                                                      NaN
# type                                                        expansion
#
#                                                                   2ED  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          white
# cards               [{'artist': 'Richard Thomas', 'cmc': 5, 'color...
# code                                                              2ED
# gathererCode                                                       2U
# magicCardsInfoCode                                                 un
# magicRaritiesCodes                                                NaN
# mkm_id                                                              3
# mkm_name                                                    Unlimited
# name                                                Unlimited Edition
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1993-12-01
# translations                                                      NaN
# type                                                             core
#
#                                                                   CED  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Richard Thomas', 'cmc': 5, 'color...
# code                                                              CED
# gathererCode                                                      NaN
# magicCardsInfoCode                                                ced
# magicRaritiesCodes                                                NaN
# mkm_id                                                             61
# mkm_name                                          Collectors' Edition
# name                                              Collector's Edition
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1993-12-01
# translations                                                      NaN
# type                                                          reprint
#
#                                                                   CEI  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Richard Thomas', 'cmc': 5, 'color...
# code                                                              CEI
# gathererCode                                                      NaN
# magicCardsInfoCode                                               cedi
# magicRaritiesCodes                                                NaN
# mkm_id                                                             77
# mkm_name                                        International Edition
# name                                International Collector's Edition
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1993-12-01
# translations                                                      NaN
# type                                                          reprint
#
#                                                                  pDRC  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Michael Whelan', 'cmc': 4, 'color...
# code                                                             pDRC
# gathererCode                                                      NaN
# magicCardsInfoCode                                                drc
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                       Dragon Con
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1994-01-01
# translations                                                      NaN
# type                                                            promo
#
#                                                                   ATQ  \
# block                                                             NaN
# booster             [uncommon, uncommon, common, common, common, c...
# border                                                          black
# cards               [{'artist': 'Margaret Organ-Kean', 'cmc': 2, '...
# code                                                              ATQ
# gathererCode                                                       AQ
# magicCardsInfoCode                                                 aq
# magicRaritiesCodes                                                NaN
# mkm_id                                                              5
# mkm_name                                                  Antiquities
# name                                                      Antiquities
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1994-03-01
# translations                                                      NaN
# type                                                        expansion
#
#                                                                   3ED  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          white
# cards               [{'artist': 'Richard Thomas', 'cmc': 5, 'color...
# code                                                              3ED
# gathererCode                                                       3E
# magicCardsInfoCode                                                 rv
# magicRaritiesCodes                                                NaN
# mkm_id                                                              6
# mkm_name                                                      Revised
# name                                                  Revised Edition
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1994-04-01
# translations        {'de': 'Unlimitierte Auflage', 'fr': 'Tirage N...
# type                                                             core
#
#                                                                   LEG  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Mark Tedin', 'cmc': 5, 'colorIden...
# code                                                              LEG
# gathererCode                                                       LE
# magicCardsInfoCode                                                 lg
# magicRaritiesCodes                                                NaN
# mkm_id                                                              7
# mkm_name                                                      Legends
# name                                                          Legends
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1994-06-01
# translations                                       {'it': 'Leggende'}
# type                                                        expansion
#
#                                                                   DRK  \
# block                                                             NaN
# booster             [uncommon, uncommon, common, common, common, c...
# border                                                          black
# cards               [{'artist': 'Mark Poole', 'cmc': 6, 'colorIden...
# code                                                              DRK
# gathererCode                                                       DK
# magicCardsInfoCode                                                 dk
# magicRaritiesCodes                                                NaN
# mkm_id                                                              8
# mkm_name                                                     The Dark
# name                                                         The Dark
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1994-08-01
# translations                                     {'it': 'L'Oscurità'}
# type                                                        expansion
#
#                                                                  pMEI  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Rob Alexander', 'foreignNames': [...
# code                                                             pMEI
# gathererCode                                                      NaN
# magicCardsInfoCode                                                mbp
# magicRaritiesCodes  [189-rarities-agent-of-artifice-novel-promo-in...
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                    Media Inserts
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1995-01-01
# translations                                                      NaN
# type                                                            promo
#
#                                                                   FEM  \
# block                                                             NaN
# booster             [uncommon, uncommon, common, common, common, c...
# border                                                          black
# cards               [{'artist': 'Heather Hudson', 'cmc': 2, 'flavo...
# code                                                              FEM
# gathererCode                                                       FE
# magicCardsInfoCode                                                 fe
# magicRaritiesCodes                                                NaN
# mkm_id                                                              9
# mkm_name                                               Fallen Empires
# name                                                   Fallen Empires
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1994-11-01
# translations                                                      NaN
# type                                                        expansion
#
#                                                                  pLGM  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Dom!', 'cmc': 2, 'colors': ['Blue...
# code                                                             pLGM
# gathererCode                                                      NaN
# magicCardsInfoCode                                              dcilm
# magicRaritiesCodes         [23-rarities-dci-legend-membership-promos]
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                Legend Membership
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1995-01-01
# translations                                                      NaN
# type                                                            promo
#
#                                                                   4ED  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          white
# cards               [{'artist': 'Mark Tedin', 'cmc': 5, 'colorIden...
# code                                                              4ED
# gathererCode                                                       4E
# magicCardsInfoCode                                                 4e
# magicRaritiesCodes                                                NaN
# mkm_id                                                             10
# mkm_name                                               Fourth Edition
# name                                                   Fourth Edition
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1995-04-01
# translations        {'de': 'Vierte Edition', 'fr': 'Quatrième Edit...
# type                                                             core
#
#                                                                   ICE  \
# block                                                         Ice Age
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Ruth Thompson', 'cmc': 4, 'colorI...
# code                                                              ICE
# gathererCode                                                       IA
# magicCardsInfoCode                                                 ia
# magicRaritiesCodes                                                NaN
# mkm_id                                                             11
# mkm_name                                                      Ice Age
# name                                                          Ice Age
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1995-06-01
# translations        {'de': 'Eiszeit', 'fr': 'Ere Glaciaire', 'it':...
# type                                                        expansion
#
#                                                                   CHR  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          white
# cards               [{'artist': 'Ken Meyer, Jr.', 'cmc': 1, 'color...
# code                                                              CHR
# gathererCode                                                       CH
# magicCardsInfoCode                                                 ch
# magicRaritiesCodes                                                NaN
# mkm_id                                                             12
# mkm_name                                                   Chronicles
# name                                                       Chronicles
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1995-07-01
# translations                                                      NaN
# type                                                          reprint
#
#                                                                   HML  \
# block                                                             NaN
# booster             [[rare, uncommon], [rare, uncommon], common, c...
# border                                                          black
# cards               [{'artist': 'Christopher Rush', 'cmc': 5, 'col...
# code                                                              HML
# gathererCode                                                       HM
# magicCardsInfoCode                                                 hl
# magicRaritiesCodes                                                NaN
# mkm_id                                                             14
# mkm_name                                                    Homelands
# name                                                        Homelands
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1995-10-01
# translations        {'de': 'Heimatländer', 'fr': 'Terres Natales',...
# type                                                        expansion
#
#                                                                   ALL  \
# block                                                         Ice Age
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Ruth Thompson', 'cmc': 3, 'flavor...
# code                                                              ALL
# gathererCode                                                       AL
# magicCardsInfoCode                                                 ai
# magicRaritiesCodes                                                NaN
# mkm_id                                                             15
# mkm_name                                                    Alliances
# name                                                        Alliances
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1996-06-10
# translations        {'de': 'Allianzen', 'fr': 'Alliances', 'it': '...
# type                                                        expansion
#
#                                                                   RQS  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          white
# cards               [{'artist': 'Harold McNeill', 'cmc': 2, 'color...
# code                                                              RQS
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                           Rivals Quick Start Set
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1996-07-01
# translations                                                      NaN
# type                                                              box
#
#                                                                  pARL  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Tony Roberts', 'foreignNames': [{...
# code                                                             pARL
# gathererCode                                                      NaN
# magicCardsInfoCode                                              arena
# magicRaritiesCodes                   [7-rarities-arena-league-promos]
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                     Arena League
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1996-08-02
# translations                                                      NaN
# type                                                            promo
#
#                                                                  pCEL  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Christopher Rush', 'cmc': 5, 'col...
# code                                                             pCEL
# gathererCode                                                      NaN
# magicCardsInfoCode                                                uqc
# magicRaritiesCodes  [353-rarities-unique-cards, 352-rarities-garfi...
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                      Celebration
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1996-08-14
# translations                                                      NaN
# type                                                            promo
#
#                                                                   MIR  \
# block                                                          Mirage
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Steve Luke', 'cmc': 4, 'colorIden...
# code                                                              MIR
# gathererCode                                                       MI
# magicCardsInfoCode                                                 mr
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                           Mirage
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1996-10-08
# translations                                                      NaN
# type                                                        expansion
#
#                                                                   MGB  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Steve White', 'cmc': 4, 'colorIde...
# code                                                              MGB
# gathererCode                                                      NaN
# magicCardsInfoCode                                               mgbc
# magicRaritiesCodes           [145-rarities-multiverse-gift-box-cards]
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                              Multiverse Gift Box
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1996-11-01
# translations                                                      NaN
# type                                                              box
#
#                                                                   ITP  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          white
# cards               [{'artist': 'Harold McNeill', 'cmc': 2, 'color...
# code                                                              ITP
# gathererCode                                                      NaN
# magicCardsInfoCode                                                itp
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                      Introductory Two-Player Set
# oldCode                                                           I2P
# onlineOnly                                                        NaN
# releaseDate                                                1996-12-31
# translations                                                      NaN
# type                                                          starter
#
#                                                                   VIS  \
# block                                                          Mirage
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Terese Nielsen', 'cmc': 5, 'color...
# code                                                              VIS
# gathererCode                                                       VI
# magicCardsInfoCode                                                 vi
# magicRaritiesCodes                                                NaN
# mkm_id                                                             17
# mkm_name                                                      Visions
# name                                                          Visions
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1997-02-03
# translations        {'de': 'Visionen', 'fr': 'Visions', 'it': 'Vis...
# type                                                        expansion
#
#                                                                   5ED  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          white
# cards               [{'artist': 'Christopher Rush', 'cmc': 5, 'col...
# code                                                              5ED
# gathererCode                                                       5E
# magicCardsInfoCode                                                 5e
# magicRaritiesCodes                                                NaN
# mkm_id                                                             23
# mkm_name                                                Fifth Edition
# name                                                    Fifth Edition
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1997-03-24
# translations        {'de': 'Fünfte Edition', 'fr': 'Cinquième Edit...
# type                                                             core
#
#                                                                  pPOD  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Andrew Robinson', 'cmc': 2, 'colo...
# code                                                             pPOD
# gathererCode                                                      NaN
# magicCardsInfoCode                                                pot
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                 Portal Demo Game
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1997-05-01
# translations                                                      NaN
# type                                                            promo
#
#                                                                   POR  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Ted Naifeh', 'cmc': 6, 'colorIden...
# code                                                              POR
# gathererCode                                                       PO
# magicCardsInfoCode                                                 po
# magicRaritiesCodes                                                NaN
# mkm_id                                                             25
# mkm_name                                                       Portal
# name                                                           Portal
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1997-05-01
# translations         {'de': 'Portal', 'fr': 'Portal', 'es': 'Portal'}
# type                                                          starter
#
#                                                                   VAN  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Ron Spencer', 'flavor': 'Ashnod s...
# code                                                              VAN
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                             69
# mkm_name                                                     Vanguard
# name                                                         Vanguard
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1997-05-01
# translations                                                      NaN
# type                                                         vanguard
#
#                                                                   WTH  \
# block                                                          Mirage
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Colin MacNeil', 'cmc': 4, 'colorI...
# code                                                              WTH
# gathererCode                                                       WL
# magicCardsInfoCode                                                 wl
# magicRaritiesCodes                                                NaN
# mkm_id                                                             18
# mkm_name                                                 Weatherlight
# name                                                     Weatherlight
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1997-06-09
# translations        {'de': 'Wetterlicht', 'fr': 'Aquilon', 'it': '...
# type                                                        expansion
#
#                                                                  pPRE  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Dan Frazier', 'cmc': 5, 'colors':...
# code                                                             pPRE
# gathererCode                                                      NaN
# magicCardsInfoCode                                                ptc
# magicRaritiesCodes             [82-rarities-prerelease-events-promos]
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                Prerelease Events
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1997-10-04
# translations                                                      NaN
# type                                                            promo
#
#                                                                   TMP  \
# block                                                         Tempest
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Alan Pollack', 'cmc': 2, 'colorId...
# code                                                              TMP
# gathererCode                                                       TE
# magicCardsInfoCode                                                 tp
# magicRaritiesCodes                                                NaN
# mkm_id                                                             19
# mkm_name                                                      Tempest
# name                                                          Tempest
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1997-10-14
# translations        {'de': 'Sturmwind', 'fr': 'Tempête', 'it': 'Te...
# type                                                        expansion
#
#                                                                   STH  \
# block                                                         Tempest
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Jeff Miracola', 'cmc': 2, 'colorI...
# code                                                              STH
# gathererCode                                                       ST
# magicCardsInfoCode                                                 sh
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                       Stronghold
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1998-03-02
# translations                                                      NaN
# type                                                        expansion
#
#                                                                   PO2  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Sam Wood', 'cmc': 4, 'colorIdenti...
# code                                                              PO2
# gathererCode                                                       P2
# magicCardsInfoCode                                                po2
# magicRaritiesCodes                                                NaN
# mkm_id                                                             24
# mkm_name                                            Portal Second Age
# name                                                Portal Second Age
# oldCode                                                           P02
# onlineOnly                                                        NaN
# releaseDate                                                1998-06-01
# translations        {'de': 'Portal Zweites Zeitalter', 'fr': 'Port...
# type                                                          starter
#
#                                                                  pJGP  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Christopher Rush', 'cmc': 1, 'col...
# code                                                             pJGP
# gathererCode                                                      NaN
# magicCardsInfoCode                                                 jr
# magicRaritiesCodes                     [56-rarities-judge-gift-cards]
# mkm_id                                                             80
# mkm_name                                         Judge Rewards Promos
# name                                               Judge Gift Program
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1998-06-01
# translations                                                      NaN
# type                                                            promo
#
#                                                                   EXO  \
# block                                                         Tempest
# booster             [rare, uncommon, uncommon, uncommon, common, c...
# border                                                          black
# cards               [{'artist': 'Randy Gallegos', 'cmc': 2, 'color...
# code                                                              EXO
# gathererCode                                                       EX
# magicCardsInfoCode                                                 ex
# magicRaritiesCodes                                                NaN
# mkm_id                                                             21
# mkm_name                                                       Exodus
# name                                                           Exodus
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1998-06-15
# translations        {'de': 'Exodus', 'fr': 'Exode', 'it': 'Esodo',...
# type                                                        expansion
#
#                                                                   UGL  \
# block                                                             NaN
# booster             [rare, uncommon, uncommon, common, common, com...
# border                                                         silver
# cards               [{'artist': 'Kaja Foglio', 'cmc': 3, 'colorIde...
# code                                                              UGL
# gathererCode                                                       UG
# magicCardsInfoCode                                                 ug
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                          Unglued
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                1998-08-11
# translations                                                      NaN
# type                                                               un
#
#                                                                  pALP  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Pete Venters', 'foreignNames': [{...
# code                                                             pALP
# gathererCode                                                      NaN
# magicCardsInfoCode                                               apac
# ...
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Titus Lunter', 'colorIdentity': [...
# code                                                              EXP
# gathererCode                                                      NaN
# magicCardsInfoCode                                                exp
# magicRaritiesCodes                                                NaN
# mkm_id                                                           1669
# mkm_name                                         Zendikar Expeditions
# name                                             Zendikar Expeditions
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2015-10-02
# translations                                                      NaN
# type                                                            promo
#
#                                                                   C15  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Victor Adame Minguez', 'cmc': 3, ...
# code                                                              C15
# gathererCode                                                      NaN
# magicCardsInfoCode                                                c15
# magicRaritiesCodes                                                NaN
# mkm_id                                                           1679
# mkm_name                                               Commander 2015
# name                                                   Commander 2015
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2015-11-13
# translations        {'de': 'Commander 2015', 'fr': 'Commander 2015...
# type                                                        commander
#
#                                                                   OGW  \
# block                                             Battle for Zendikar
# booster             [[rare, mythic rare], uncommon, uncommon, unco...
# border                                                          black
# cards               [{'artist': 'Viktor Titov', 'cmc': 7, 'foreign...
# code                                                              OGW
# gathererCode                                                      NaN
# magicCardsInfoCode                                                ogw
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                            Oath of the Gatewatch
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-01-22
# translations        {'pt': 'Juramento das Sentinelas', 'es': 'El j...
# type                                                        expansion
#
#                                                                   DDQ  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Daarken', 'cmc': 3, 'colorIdentit...
# code                                                              DDQ
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                   Duel Decks: Blessed vs. Cursed
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-02-26
# translations                 {'jp': 'Duel Decks: Blessed vs. Cursed'}
# type                                                        duel deck
#
#                                                                   W16  \
# block                                          Shadows over Innistrad
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Aleksi Briclot', 'cmc': 6, 'color...
# code                                                              W16
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                Welcome Deck 2016
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-04-08
# translations                                                      NaN
# type                                                          starter
#
#                                                                   SOI  \
# block                                          Shadows over Innistrad
# booster             [[rare, mythic rare], uncommon, uncommon, unco...
# border                                                          black
# cards               [{'artist': 'Chase Stone', 'cmc': 3, 'colorIde...
# code                                                              SOI
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                           Shadows over Innistrad
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-04-08
# translations        {'de': 'Schatten über Innistrad', 'fr': 'Ténèb...
# type                                                        expansion
#
#                                                                   EMA  \
# block                                                             NaN
# booster             [[rare, mythic rare], uncommon, uncommon, unco...
# border                                                          black
# cards               [{'artist': 'Don Hazeltine', 'cmc': 3, 'colorI...
# code                                                              EMA
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                  Eternal Masters
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-06-10
# translations                       {'jp': 'エターナルマスターズ', 'cn': '经典大师'}
# type                                                          reprint
#
#                                                                   EMN  \
# block                                          Shadows over Innistrad
# booster             [[rare, mythic rare], uncommon, uncommon, unco...
# border                                                          black
# cards               [{'artist': 'Greg Staples', 'cmc': 8, 'colorId...
# code                                                              EMN
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                    Eldritch Moon
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-07-22
# translations                                                      NaN
# type                                                        expansion
#
#                                                                   V16  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Jason Chan', 'cmc': 6, 'colorIden...
# code                                                              V16
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                             From the Vault: Lore
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-08-19
# translations                                                      NaN
# type                                                   from the vault
#
#                                                                   CN2  \
# block                                                             NaN
# booster             [[rare, mythic rare], uncommon, uncommon, unco...
# border                                                          black
# cards               [{'artist': 'Lius Lasahido', 'colorIdentity': ...
# code                                                              CN2
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                       Conspiracy: Take the Crown
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-08-26
# translations        {'jp': 'Conspiracy: Take the Crown', 'cn': 'Co...
# type                                                       conspiracy
#
#                                                                   DDR  \
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Raymond Swanland', 'cmc': 3, 'col...
# code                                                              DDR
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                 Duel Decks: Nissa vs. Ob Nixilis
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-09-02
# translations                                                      NaN
# type                                                        duel deck
#
#                                                                   KLD  \
# block                                                             NaN
# booster             [[rare, mythic rare], uncommon, uncommon, unco...
# border                                                          black
# cards               [{'artist': 'Winona Nelson', 'cmc': 3, 'colorI...
# code                                                              KLD
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                                         Kaladesh
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-09-30
# translations                                                      NaN
# type                                                        expansion
#
#                                                                   MPS
# block                                                             NaN
# booster                                                           NaN
# border                                                          black
# cards               [{'artist': 'Raoul Vitale', 'cmc': 1, 'id': 'b...
# code                                                              MPS
# gathererCode                                                      NaN
# magicCardsInfoCode                                                NaN
# magicRaritiesCodes                                                NaN
# mkm_id                                                            NaN
# mkm_name                                                          NaN
# name                                              Kaladesh Inventions
# oldCode                                                           NaN
# onlineOnly                                                        NaN
# releaseDate                                                2016-09-30
# translations                                                      NaN
# type                                                      masterpiece

# %%
#Desplegar información general
print("Tipo de dato:", type(raw))
print("\n---> Dimensiones:", raw.shape)
print("\n---> Columnas:\n", raw.columns.values)

print("\n---> Llaves:\n", raw.keys())
print("\n---> Índices:\n", raw.index)

#Primeros datos
print("\n---> Primer renglón\n", raw.head(1))
print("\n---> Primer columna\n", raw.transpose().head(1))
print("\n---> Acceso por llaves ('10E')\n", raw['10E'])
print("\n---> Acceso por índices ('border')\n", raw.loc['border'][0])
# Out:
# Tipo de dato: <class 'pandas.core.frame.DataFrame'>
#
# ---> Dimensiones: (16, 199)
#
# ---> Columnas:
#  ['LEA' 'LEB' 'ARN' '2ED' 'CED' 'CEI' 'pDRC' 'ATQ' '3ED' 'LEG' 'DRK' 'pMEI'
#  'FEM' 'pLGM' '4ED' 'ICE' 'CHR' 'HML' 'ALL' 'RQS' 'pARL' 'pCEL' 'MIR' 'MGB'
#  'ITP' 'VIS' '5ED' 'pPOD' 'POR' 'VAN' 'WTH' 'pPRE' 'TMP' 'STH' 'PO2' 'pJGP'
#  'EXO' 'UGL' 'pALP' 'USG' 'ATH' 'ULG' '6ED' 'PTK' 'UDS' 'S99' 'pGRU' 'pWOR'
#  'pWOS' 'MMQ' 'BRB' 'pSUS' 'pFNM' 'pELP' 'NMS' 'S00' 'PCY' 'BTD' 'INV'
#  'PLS' '7ED' 'pMPR' 'APC' 'ODY' 'DKM' 'TOR' 'JUD' 'ONS' 'LGN' 'SCG' 'pREL'
#  '8ED' 'MRD' 'DST' '5DN' 'CHK' 'UNH' 'BOK' 'SOK' '9ED' 'RAV' 'p2HG' 'pGTW'
#  'GPT' 'pCMP' 'DIS' 'CSP' 'CST' 'TSP' 'TSB' 'pHHO' 'PLC' 'pPRO' 'pGPX'
#  'FUT' '10E' 'pMGD' 'MED' 'LRW' 'EVG' 'pLPA' 'MOR' 'p15A' 'SHM' 'pSUM'
#  'EVE' 'DRB' 'ME2' 'pWPN' 'ALA' 'DD2' 'CON' 'DDC' 'ARB' 'M10' 'V09' 'HOP'
#  'ME3' 'ZEN' 'DDD' 'H09' 'WWK' 'DDE' 'ROE' 'DPA' 'ARC' 'M11' 'V10' 'DDF'
#  'SOM' 'PD2' 'ME4' 'MBS' 'DDG' 'NPH' 'CMD' 'M12' 'V11' 'DDH' 'ISD' 'PD3'
#  'DKA' 'DDI' 'AVR' 'PC2' 'M13' 'V12' 'DDJ' 'RTR' 'CM1' 'GTC' 'DDK' 'pWCQ'
#  'DGM' 'MMA' 'M14' 'V13' 'DDL' 'THS' 'C13' 'BNG' 'DDM' 'JOU' 'MD1' 'CNS'
#  'VMA' 'M15' 'CPK' 'V14' 'DDN' 'KTK' 'C14' 'DD3_DVD' 'DD3_EVG' 'DD3_GVL'
#  'DD3_JVC' 'FRF_UGIN' 'FRF' 'DDO' 'DTK' 'TPR' 'MM2' 'ORI' 'V15' 'DDP' 'BFZ'
#  'EXP' 'C15' 'OGW' 'DDQ' 'W16' 'SOI' 'EMA' 'EMN' 'V16' 'CN2' 'DDR' 'KLD'
#  'MPS']
#
# ---> Llaves:
#  Index(['LEA', 'LEB', 'ARN', '2ED', 'CED', 'CEI', 'pDRC', 'ATQ', '3ED', 'LEG',
#        ...
#        'DDQ', 'W16', 'SOI', 'EMA', 'EMN', 'V16', 'CN2', 'DDR', 'KLD', 'MPS'],
#       dtype='object', length=199)
#
# ---> Índices:
#  Index(['block', 'booster', 'border', 'cards', 'code', 'gathererCode',
#        'magicCardsInfoCode', 'magicRaritiesCodes', 'mkm_id', 'mkm_name',
#        'name', 'oldCode', 'onlineOnly', 'releaseDate', 'translations', 'type'],
#       dtype='object')
#
# ---> Primer renglón
#         LEA  LEB  ARN  2ED  CED  CEI pDRC  ATQ  3ED  LEG  DRK pMEI  FEM pLGM  \
# block  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        4ED      ICE  CHR  HML      ALL  RQS pARL pCEL     MIR  MGB  ITP  \
# block  NaN  Ice Age  NaN  NaN  Ice Age  NaN  NaN  NaN  Mirage  NaN  NaN
#
#           VIS  5ED pPOD  POR  VAN     WTH pPRE      TMP      STH  PO2 pJGP  \
# block  Mirage  NaN  NaN  NaN  NaN  Mirage  NaN  Tempest  Tempest  NaN  NaN
#
#            EXO  UGL pALP     USG  ATH     ULG  6ED  PTK     UDS  S99 pGRU  \
# block  Tempest  NaN  NaN  Urza's  NaN  Urza's  NaN  NaN  Urza's  NaN  NaN
#
#       pWOR pWOS      MMQ  BRB pSUS pFNM pELP      NMS  S00      PCY  BTD  \
# block  NaN  NaN  Masques  NaN  NaN  NaN  NaN  Masques  NaN  Masques  NaN
#
#             INV       PLS  7ED pMPR       APC      ODY  DKM      TOR      JUD  \
# block  Invasion  Invasion  NaN  NaN  Invasion  Odyssey  NaN  Odyssey  Odyssey
#
#              ONS        LGN        SCG pREL  8ED       MRD       DST  \
# block  Onslaught  Onslaught  Onslaught  NaN  NaN  Mirrodin  Mirrodin
#
#             5DN       CHK  UNH       BOK       SOK  9ED      RAV p2HG pGTW  \
# block  Mirrodin  Kamigawa  NaN  Kamigawa  Kamigawa  NaN  Ravnica  NaN  NaN
#
#            GPT pCMP      DIS      CSP  CST          TSP          TSB pHHO  \
# block  Ravnica  NaN  Ravnica  Ice Age  NaN  Time Spiral  Time Spiral  NaN
#
#                PLC pPRO pGPX          FUT  10E pMGD  MED     LRW  EVG pLPA  \
# block  Time Spiral  NaN  NaN  Time Spiral  NaN  NaN  NaN  Lorwyn  NaN  NaN
#
#           MOR p15A         SHM pSUM         EVE  DRB  ME2 pWPN    ALA  DD2  \
# block  Lorwyn  NaN  Shadowmoor  NaN  Shadowmoor  NaN  NaN  NaN  Alara  NaN
#
#          CON  DDC    ARB  M10  V09  HOP  ME3       ZEN  DDD  H09       WWK  \
# block  Alara  NaN  Alara  NaN  NaN  NaN  NaN  Zendikar  NaN  NaN  Zendikar
#
#        DDE       ROE  DPA  ARC  M11  V10  DDF                SOM  PD2  ME4  \
# block  NaN  Zendikar  NaN  NaN  NaN  NaN  NaN  Scars of Mirrodin  NaN  NaN
#
#                      MBS  DDG                NPH  CMD  M12  V11  DDH  \
# block  Scars of Mirrodin  NaN  Scars of Mirrodin  NaN  NaN  NaN  NaN
#
#              ISD  PD3        DKA  DDI        AVR  PC2  M13  V12  DDJ  \
# block  Innistrad  NaN  Innistrad  NaN  Innistrad  NaN  NaN  NaN  NaN
#
#                      RTR  CM1                GTC  DDK pWCQ                DGM  \
# block  Return to Ravnica  NaN  Return to Ravnica  NaN  NaN  Return to Ravnica
#
#        MMA  M14  V13  DDL     THS  C13     BNG  DDM     JOU  MD1  CNS  VMA  \
# block  NaN  NaN  NaN  NaN  Theros  NaN  Theros  NaN  Theros  NaN  NaN  NaN
#
#        M15  CPK  V14  DDN              KTK  C14 DD3_DVD DD3_EVG DD3_GVL  \
# block  NaN  NaN  NaN  NaN  Khans of Tarkir  NaN     NaN     NaN     NaN
#
#       DD3_JVC FRF_UGIN              FRF  DDO              DTK  TPR  MM2  ORI  \
# block     NaN      NaN  Khans of Tarkir  NaN  Khans of Tarkir  NaN  NaN  NaN
#
#        V15  DDP                  BFZ  EXP  C15                  OGW  DDQ  \
# block  NaN  NaN  Battle for Zendikar  NaN  NaN  Battle for Zendikar  NaN
#
#                           W16                     SOI  EMA  \
# block  Shadows over Innistrad  Shadows over Innistrad  NaN
#
#                           EMN  V16  CN2  DDR  KLD  MPS
# block  Shadows over Innistrad  NaN  NaN  NaN  NaN  NaN
#
# ---> Primer columna
#      block                                            booster border  \
# LEA   NaN  [rare, uncommon, uncommon, uncommon, common, c...  black
#
#                                                  cards code gathererCode  \
# LEA  [{'artist': 'Richard Thomas', 'cmc': 5, 'color...  LEA           1E
#
#     magicCardsInfoCode magicRaritiesCodes mkm_id mkm_name  \
# LEA                 al                NaN      1    Alpha
#
#                       name oldCode onlineOnly releaseDate translations  type
# LEA  Limited Edition Alpha     NaN        NaN  1993-08-05          NaN  core
#
# ---> Acceso por llaves ('10E')
#  block                                                               NaN
# booster               [rare, uncommon, uncommon, uncommon, common, c...
# border                                                            black
# cards                 [{'artist': 'Pete Venters', 'cmc': 7, 'colorId...
# code                                                                10E
# gathererCode                                                        NaN
# magicCardsInfoCode                                                  10e
# magicRaritiesCodes                                                  NaN
# mkm_id                                                               74
# mkm_name                                                  Tenth Edition
# name                                                      Tenth Edition
# oldCode                                                             NaN
# onlineOnly                                                          NaN
# releaseDate                                                  2007-07-13
# translations          {'de': 'Zehnte Edition', 'fr': 'Dixième éditio...
# type                                                               core
# Name: 10E, dtype: object
#
# ---> Acceso por índices ('border')
#  black

# %% [markdown]
# Una descripción de los códigos [aquí](http://mtgsalvation.gamepedia.com/Set#Expansion_sets)
#
# <table border="1" cellpadding="5" style="background-color:#FFFFFF;">
# <tr>
# <th scope="col" style="width:5em;"> Released
# </th>
# <th scope="col" style="width:18em;"> Set
# </th>
# <th scope="col" style="width:6em;"> Code
# </th>
# <th scope="col" style="width:8em;"> Type
# </th>
# </tr>
# <tr>
# <td> 1993-08 </td>
# <td> <i>Alpha (Limited Edition)</i> </td>
# <td> LEA (A) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 1993-10 </td>
# <td> <i>Beta (Limited Edition)</i> </td>
# <td> LEB (B) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 1993-12 </td>
# <td> <i>Unlimited Edition</i> </td>
# <td> 2ED (U) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 1993-12 </td>
# <td> <i>Arabian Nights</i> </td>
# <td> ARN (AN) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1994-03 </td>
# <td> <i>Antiquities</i> </td>
# <td>ATQ (AQ) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1994-04 </td>
# <td> <i>Revised Edition</i> </td>
# <td> 3ED (RV) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 1994-06 </td>
# <td> <i>Legends</i> </td>
# <td> LEG (LE) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1994-08 </td>
# <td> <i>The Dark</i> </td>
# <td> DRK (DK) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1994-11 </td>
# <td> <i>Fallen Empires</i> </td>
# <td> FEM (FE) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1995-05 </td>
# <td> <i>4th Edition</i> </td>
# <td> 4ED (4E) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 1995-06 </td>
# <td> <i>Ice Age</i> </td>
# <td> ICE (IA) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1995-07 </td>
# <td> <i> Chronicles</i> </td>
# <td> CHR (CH) </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 1995-08 </td>
# <td> <i> Renaissance</i> </td>
# <td> </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 1995-10 </td>
# <td> <i> Homelands</i> </td>
# <td> HML (HL) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1996-06 </td>
# <td> <i> Alliances</i> </td>
# <td> ALL (AL) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1996-10 </td>
# <td> <i> Mirage</i> </td>
# <td> MIR (MI) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1997-02 </td>
# <td> <i> Visions</i> </td>
# <td> VIS (VI) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1997-03 </td>
# <td> <i> 5th Edition</i> </td>
# <td> 5ED (5E) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 1997-05 </td>
# <td> <i> Portal</i> </td>
# <td> POR (PO) </td>
# <td> Starter set </td>
# </tr>
# <tr>
# <td> 1997-06 </td>
# <td> <i> Weatherlight</i> </td>
# <td> WTH (WL) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1997-10 </td>
# <td> <i>Tempest</i> </td>
# <td> TMP (TE) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1998-02 </td>
# <td> <i> Stronghold</i> </td>
# <td> STH (ST) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1998-06 </td>
# <td> <i> Exodus</i> </td>
# <td> EXO (EX) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1998-06 </td>
# <td> <i> Portal Second Age</i> </td>
# <td> P02 (P2) </td>
# <td> Starter set </td>
# </tr>
# <tr>
# <td> 1998-08 </td>
# <td> <i> Unglued</i> </td>
# <td> UGL (UG) </td>
# <td> Un-set </td>
# </tr>
# <tr>
# <td> 1998-10 </td>
# <td> <i> Urza's Saga</i> </td>
# <td> USG (US) </td>
# <td> Expansion set </td></tr>
# <tr>
# <td> 1998-11 </td>
# <td> <i> Anthologies</i> </td>
# <td> ATH </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 1999-02 </td>
# <td> <i> Urza's Legacy</i> </td>
# <td> ULG (UL) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1999-04 </td>
# <td> <i> 6th Edition</i> </td>
# <td> 6ED (6E) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 1999-06 </td>
# <td> <i> Urza's Destiny</i> </td>
# <td> UDS (UD) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1999-07 </td>
# <td> <i> Portal Three Kingdoms</i> </td>
# <td> PTK (P3) </td>
# <td> Starter set </td>
# </tr>
# <tr>
# <td> 1999-08 </td>
# <td> <i> Starter 1999</i> </td>
# <td> S99 </td>
# <td> Starter set </td>
# </tr>
# <tr>
# <td> 1999-09 </td>
# <td> <i> Mercadian Masques</i> </td>
# <td> MMQ (MM) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 1999-11 </td>
# <td> <i> Battle Royale</i> </td>
# <td> BRB </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2000-02 </td>
# <td> <i> Nemesis</i> </td>
# <td> NEM (NE) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2000-04 </td>
# <td> <i> Starter 2000</i> </td>
# <td> S00 </td>
# <td> Starter set </td>
# </tr>
# <tr>
# <td> 2000-06 </td>
# <td> <i> Prophecy</i> </td>
# <td> PCY (PR) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2000-09 </td>
# <td> <i> Invasion</i> </td>
# <td> INV (IN) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2000-10 </td>
# <td> <i> Beatdown</i> </td>
# <td> BTD </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2001-01 </td>
# <td> <i> Planeshift</i> </td>
# <td> PLS (PL) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2001-04 </td>
# <td> <i>7th Edition</i> </td>
# <td> 7ED (7E) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2001-05 </td>
# <td> <i> Apocalypse</i> </td>
# <td> APC (AP) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2001-10 </td>
# <td> <i> Odyssey</i> </td>
# <td> ODY (OD) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2001-12 </td>
# <td> <i> Deckmasters 2001</i> </td>
# <td> DKM </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2002-02 </td>
# <td> <i> Torment</i> </td>
# <td> TOR (TO) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2002-05 </td>
# <td> <i> Judgment</i> </td>
# <td> JUD (JU) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2002-10 </td>
# <td> <i> Onslaught</i> </td>
# <td> ONS (ON) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2003-01 </td>
# <td> <i> Legions</i> </td>
# <td> LGN (LE) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2003-05 </td>
# <td> <i> Scourge</i> </td>
# <td>SCG (SC) </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2003-07 </td>
# <td> <i> 8th Edition</i> </td>
# <td> 8ED (8E) </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2003-10 </td>
# <td> <i> Mirrodin</i> </td>
# <td> MRD </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2004-02 </td>
# <td> <i> Darksteel</i> </td>
# <td> DST </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2004-06 </td>
# <td> <i> Fifth Dawn</i> </td>
# <td> 5DN </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2004-10 </td>
# <td> <i> Champions of Kamigawa</i> </td>
# <td> CHK </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2004-11 </td>
# <td> <i> Unhinged</i> </td>
# <td> UNH </td>
# <td> Un-set </td>
# </tr>
# <tr>
# <td> 2005-02 </td>
# <td> <i> Betrayers of Kamigawa</i> </td>
# <td> BOK </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2005-06 </td>
# <td> <i> Saviors of Kamigawa</i> </td>
# <td> SOK </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2005-07 </td>
# <td> <i> 9th Edition</i> </td>
# <td> 9ED </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2005-10 </td>
# <td> <i> Ravnica: City of Guilds</i> </td>
# <td> RAV </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2006-02 </td>
# <td> <i> Guildpact</i> </td>
# <td> GPT </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2006-05 </td>
# <td> <i> Dissension</i> </td>
# <td> DIS </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2006-07 </td>
# <td> <i> Coldsnap</i> </td>
# <td> CSP </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2006-10 </td>
# <td> <i> Time Spiral</i> </td>
# <td> TSP/TSB </td>
# <td>Expansion set </td>
# </tr>
# <tr>
# <td> 2007-02 </td>
# <td> <i> Planar Chaos</i> </td>
# <td> PLC </td>
# <td>Expansion set </td>
# </tr>
# <tr>
# <td> 2007-05 </td>
# <td> <i> Future Sight</i> </td>
# <td> FUT </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2007-07 </td>
# <td> <i> 10th Edition</i> </td>
# <td> 10E </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2007-09 </td>
# <td> <i> Masters Edition</i> </td>
# <td> MED </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2007-10 </td>
# <td> <i> Lorwyn</i> </td>
# <td> LRW </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2007-11 </td>
# <td> <i> Duel Decks: Elves vs. Goblins</i> </td>
# <td> EVG </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2008-02 </td>
# <td> <i> Morningtide</i> </td>
# <td> MOR </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2008-05 </td>
# <td> <i> Shadowmoor</i> </td>
# <td> SHM </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2008-06 </td>
# <td> <i> Eventide</i> </td>
# <td> EVE </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2008-08 </td>
# <td> <i> From the Vault: Dragons</i> </td>
# <td> DRB </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2008-09 </td>
# <td> <i> Masters Edition II</i> </td>
# <td> ME2 </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2008-09 </td>
# <td> <i> Shards of Alara</i> </td>
# <td> ALA </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2008-11 </td>
# <td> <i> Duel Decks: Jace vs. Chandra</i> </td>
# <td> DD2 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2009-02 </td>
# <td> <i> Conflux</i> </td>
# <td> CON </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2009-04 </td>
# <td> <i> Duel Decks: Divine vs. Demonic</i> </td>
# <td> DDC </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2009-04 </td>
# <td> <i> Alara Reborn</i> </td>
# <td> ARB </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2009-07 </td>
# <td> <i> Magic 2010</i> </td>
# <td> M10 </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2009-08 </td>
# <td> <i> Commander Theme Decks</i> </td>
# <td> TD0 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2009-08 </td>
# <td> <i> From the Vault: Exiled</i> </td>
# <td> V09 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2009-09 </td>
# <td> <i> Planechase (2009)</i> </td>
# <td> HOP </td>
# <td> Supplemental set </td>
# </tr>
# <tr>
# <td> 2009-09 </td>
# <td> <i> Masters Edition III</i> </td>
# <td> ME3 </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2009-10 </td>
# <td> <i> Zendikar</i> </td>
# <td> ZEN </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2009-10 </td>
# <td> <i> Duel Decks: Garruk vs. Liliana</i> </td>
# <td> DDD </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2009-11 </td>
# <td> <i> Premium Deck Series: Slivers</i> </td>
# <td> H09 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2010-02 </td>
# <td> <i> Worldwake</i> </td>
# <td> WWK </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2010-03 </td>
# <td> <i> Duel Decks: Phyrexia vs. The Coalition</i> </td>
# <td> DDE </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2010-04 </td>
# <td> <i> Rise of the Eldrazi</i> </td>
# <td> ROE </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2010-05 </td>
# <td> <i> Deck Builder's Toolkit (2010)</i> </td>
# <td> </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2010-06 </td>
# <td> <i> Duels of the Planeswalkers</i> </td>
# <td> DPA </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2010-06 </td>
# <td> <i> Archenemy</i> </td>
# <td> ARC </td>
# <td> Supplemental set </td>
# </tr>
# <tr>
# <td> 2010-07 </td>
# <td> <i> Magic 2011</i> </td>
# <td> M11 </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2010-08 </td>
# <td> <i> From the Vault: Relics</i> </td>
# <td> V10 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2010-09 </td>
# <td> <i> Duel Decks: Elspeth vs. Tezzeret</i> </td>
# <td> DDF </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2010-10 </td>
# <td> <i> Scars of Mirrodin</i> </td>
# <td> SOM </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2010-11 </td>
# <td> <i> Magic Online Deck Series</i> </td>
# <td> TD0 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2010-11 </td>
# <td> <i> Premium Deck Series: Fire &amp; Lightning</i> </td>
# <td> PD2 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2010-11 </td>
# <td> <i> Momir Basic Event Deck</i> </td>
# <td> </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2011-01 </td>
# <td> <i> Masters Edition IV</i> </td>
# <td> ME4 </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2011-02 </td>
# <td> <i> Mirrodin Besieged</i> </td>
# <td> MBS </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2011-03 </td>
# <td> <i> Deck Builder's Toolkit (2011)</i> </td>
# <td align="center"> </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2011-04 </td>
# <td> <i> Duel Decks: Knights vs. Dragons</i> </td>
# <td> DDG </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2011-05 </td>
# <td> <i> New Phyrexia</i> </td>
# <td> NPH </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2011-06 </td>
# <td> <i> Commander (2011)</i> </td>
# <td> CMD </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2011-07 </td>
# <td> <i> Magic 2012</i> </td>
# <td> M12 </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2011-08 </td>
# <td> <i> From the Vault: Legends</i> </td>
# <td> V11 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2011-09 </td>
# <td> <i> Duel Decks: Ajani vs. Nicol Bolas</i> </td>
# <td> DDH </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2011-09 </td>
# <td> <i> Innistrad</i> </td>
# <td> ISD </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2011-11 </td>
# <td> <i> Premium Deck Series: Graveborn</i> </td>
# <td> PD3 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2012-02 </td>
# <td> <i> Dark Ascension</i> </td>
# <td> DKA </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2012-03 </td>
# <td> <i> Duel Decks: Venser vs. Koth</i> </td>
# <td> DDI </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2012-05 </td>
# <td> <i> Avacyn Restored</i> </td>
# <td> AVR </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2012-05 </td>
# <td> <i> Planechase 2012</i> </td>
# <td> PC2 </td>
# <td> Supplemental set </td>
# </tr>
# <tr>
# <td> 2012-07 </td>
# <td> <i> Magic 2013</i> </td>
# <td> M13 </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2012-08 </td>
# <td> <i> From the Vault: Realms</i> </td>
# <td> V12 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2012-09 </td>
# <td> <i> Duel Decks: Izzet vs. Golgari</i> </td>
# <td> DDJ </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2012-10 </td>
# <td>  Return to Ravnica</i> </td>
# <td> RTR </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2012-11 </td>
# <td> <i> Commander's Arsenal</i> </td>
# <td> CM1 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2013-01 </td>
# <td> <i> Duel Decks: Mirrodin Pure vs. New Phyrexia</i> </td>
# <td> TD2 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2013-02 </td>
# <td> <i> Gatecrash</i> </td>
# <td> GTC </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2013-03 </td>
# <td> <i> Duel Decks: Sorin vs. Tibalt</i> </td>
# <td> DDK </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2013-05 </td>
# <td> <i> Dragon's Maze</i> </td>
# <td> DGM </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2013-06 </td>
# <td> <i> Modern Masters (2013)</i> </td>
# <td> MMA </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2013-07 </td>
# <td> <i> Magic 2014</i> </td>
# <td> M14 </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2013-08 </td>
# <td> <i> From the Vault: Twenty</i> </td>
# <td> V13 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2013-09 </td>
# <td> <i> Duel Decks: Heroes vs. Monsters</i> </td>
# <td> DDL </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2013-09 </td>
# <td> <i> Theros</i> </td>
# <td> THS </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2013-11 </td>
# <td> <i> Commander 2013 </i> </td>
# <td> C13 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2014-02 </td>
# <td> <i> Born of the Gods</i> </td>
# <td> BNG </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2014-03 </td>
# <td> <i> Duel Decks: Jace vs. Vraska</i> </td>
# <td> DDM </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2014-05 </td>
# <td> <i> Journey into Nyx</i> </td>
# <td> JOU </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2014-05 </td>
# <td> <i> Modern Event Deck</i> </td>
# <td> MD1 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2014-06 </td>
# <td> <i> Conspiracy</i> </td>
# <td> CNS </td>
# <td> Supplemental set </td>
# </tr>
# <tr>
# <td> 2014-06 </td>
# <td> <i> Vintage Masters</i> </td>
# <td> VMA </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2014-07 </td>
# <td> <i> Magic 2015</i> </td>
# <td> M15 </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2014-08 </td>
# <td> <i> From the Vault: Annihilation</i> </td>
# <td> V14</td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2014-10 </td>
# <td> <i> Duel Decks: Speed vs. Cunning</i> </td>
# <td> DDN </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2014-10 </td>
# <td> <i> Khans of Tarkir </td></i>
# <td> KTK </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2014-11 </td>
# <td> <i> Commander 2014</i> </td>
# <td> C14 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2014-12 </td>
# <td> <i> Duel Decks Anthology</i> </td>
# <td> DD3 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2015-01 </td>
# <td> <i> Fate Reforged</i> </td>
# <td> FRF </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2015-02 </td>
# <td> <i> Duel Decks: Elspeth vs. Kiora</i> </td>
# <td> DDO </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2015-03 </td>
# <td> <i> Dragons of Tarkir </td></i>
# <td> DTK </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2015-05 </td>
# <td> <i> Tempest Remastered</i> </td>
# <td> TPR </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2015-05 </td>
# <td> <i> Modern Masters 2015</i> </td>
# <td> MM2 </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2015-07 </td>
# <td> <i> Magic Origins</i> </td>
# <td> ORI </td>
# <td> Core set </td>
# </tr>
# <tr>
# <td> 2015-08 </td>
# <td> <i> From the Vault: Angels</i> </td>
# <td> V15 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2015-08 </td>
# <td> <i> Duel Decks: Zendikar vs. Eldrazi</i> </td>
# <td> DDP </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2015-10 </td>
# <td> <i> Battle for Zendikar</i> </td>
# <td> BFZ </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2015-10<br />2016-01 </td>
# <td> <i> Zendikar Expeditions</i> </td>
# <td> EXP </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2015-11 </td>
# <td> <i> Commander 2015</i> </td>
# <td> C15 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2015-11 </td>
# <td> <i> Legendary Cube</i> </td>
# <td> PZ1 </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2016-01 </td>
# <td> <i> Oath of the Gatewatch</i> </td>
# <td> OGW </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2016-02 </td>
# <td> <i> Duel Decks: Blessed vs. Cursed</i> </td>
# <td> DDQ </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2016-04 </td>
# <td> <i> Welcome Deck 2016</i> </td>
# <td> W16 </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2016-04 </td>
# <td> <i> Shadows over Innistrad</i> </td>
# <td> SOI </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2016-06 </td>
# <td> <i> Eternal Masters</i> </td>
# <td> EMA </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2016-07 </td>
# <td> <i> Eldritch Moon</i> </td>
# <td> EMN </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2016-08 </td>
# <td> <i> From the Vault: Lore</i> </td>
# <td> V16 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2016-08 </td>
# <td> <i> Conspiracy: Take the Crown</i> </td>
# <td> CN2 </td>
# <td> Supplemental set </td>
# </tr>
# <tr>
# <td> 2016-09 </td>
# <td> <i> Duel Decks: Nissa vs. Ob Nixilis</i> </td>
# <td> DDR </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2016-09 </td>
# <td> <i> Kaladesh</i> </td>
# <td> KLD </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2016-09<br />2017-01 </td>
# <td> <i> Kaladesh Inventions</i> </td>
# <td> MPS </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2016-11 </td>
# <td> <i> Commander 2016</i> </td>
# <td> C16 </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2016-11 </td>
# <td> <i> You Make the Cube</i> </td>
# <td> </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2016-11 </td>
# <td> <i> Planechase Anthology</i> </td>
# <td> PCA </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2017-01 </td>
# <td> <i> Aether Revolt</i> </td>
# <td> AER </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2017-03 </td>
# <td> <i> Modern Masters 2017</i> </td>
# <td> MM3 </td>
# <td> Compilation set </td>
# </tr>
# <tr>
# <td> 2017-03 </td>
# <td> <i> Duel Decks: Mind vs. Might</i> </td>
# <td> DDS </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2017-04 </td>
# <td> <i> Amonkhet</i> </td>
# <td> AKH </td>
# <td> Expansion set </td>
# </tr>
# <tr>
# <td> 2017-06 </td>
# <td> <i> Commander Anthology</i> </td>
# <td> CMA </td>
# <td> Box set </td>
# </tr>
# <tr>
# <td> 2017-06 </td>
# <td> <i> Archenemy: Nicol Bolas</i> </td>
# <td> </td>
# <td> Supplemental set </td>
# </tr>
# <tr>
# <td> 2017-07 </td>
# <td> <i> Hour of Devastation</i> </td>
# <td> HOU </td>
# <td> Expansion set </td>
# </tr></table>

# %%
print("Número de cartas en el set", len(raw.iloc[3]['LEA']))
display(raw.iloc[3]['LEA'][0])
display(HTML('<br><img src="images/air_elemental_card.jpg"><br>'))
# Out:
# Número de cartas en el set 295
# {'artist': 'Richard Thomas',
#  'cmc': 5,
#  'colorIdentity': ['U'],
#  'colors': ['Blue'],
#  'flavor': 'These spirits of the air are winsome and wild, and cannot be truly contained. Only marginally intelligent, they often substitute whimsy for strategy, delighting in mischief and mayhem.',
#  'id': '926234c2fe8863f49220a878346c4c5ca79b6046',
#  'imageName': 'air elemental',
#  'layout': 'normal',
#  'legalities': [{'format': 'Commander', 'legality': 'Legal'},
#   {'format': 'Legacy', 'legality': 'Legal'},
#   {'format': 'Modern', 'legality': 'Legal'},
#   {'format': 'Vintage', 'legality': 'Legal'}],
#  'manaCost': '{3}{U}{U}',
#  'mciNumber': '47',
#  'multiverseid': 94,
#  'name': 'Air Elemental',
#  'originalText': 'Flying',
#  'originalType': 'Summon — Elemental',
#  'power': '4',
#  'printings': ['LEA',
#   'LEB',
#   '2ED',
#   'CED',
#   'CEI',
#   '3ED',
#   '4ED',
#   '5ED',
#   'PO2',
#   '6ED',
#   'S99',
#   'BRB',
#   'BTD',
#   '7ED',
#   '8ED',
#   '9ED',
#   '10E',
#   'DD2',
#   'M10',
#   'DPA',
#   'ME4',
#   'DD3_JVC'],
#  'rarity': 'Uncommon',
#  'subtypes': ['Elemental'],
#  'text': 'Flying',
#  'toughness': '4',
#  'type': 'Creature — Elemental',
#  'types': ['Creature']}
# <br><img src="images/air_elemental_card.jpg"><br>

# %%
# Aux variables
keeps = ['name', 'colors', 'types', 'cmc', 'power', 'toughness']

# Data fusion
mtg = []
for col in raw.columns.values:
    release = pd.DataFrame(raw[col]['cards'])
    release = release.reindex(keeps, axis="columns")
    mtg.append(release)
mtg = pd.concat(mtg)

#Convertir 'power' y 'toughness' a valores numéricos
mtg[['power','toughness']] = mtg[['power','toughness']].apply(pd.to_numeric, errors='coerce')

#Eliminar datos con valores nulos
mtg = mtg.dropna()

#Convertir 'colors' y 'types' a su primer valor
f = lambda x: x[0]
mtg['colors'] = mtg['colors'].map(f)
mtg['types'] = mtg['types'].map(f)

print(mtg.describe(), "\n")

#Tomar una muestra y describir los datos
mtgs = mtg.sample(10)
print(mtgs)
print(mtgs.describe())
# Out:
#                 cmc         power     toughness
# count  13549.000000  13549.000000  13549.000000
# mean       3.625729      2.509669      2.693594
# std        1.703889      1.870794      1.878510
# min        0.000000     -1.000000      0.000000
# 25%        2.000000      1.000000      1.000000
# 50%        3.000000      2.000000      2.000000
# 75%        5.000000      3.000000      4.000000
# max       15.000000     99.000000     99.000000
#
#                        name colors     types  cmc  power  toughness
# 41                Lady Orca  Black  Creature  7.0    7.0        4.0
# 9           Loyal Retainers  White  Creature  3.0    1.0        1.0
# 30            Murk Dwellers  Black  Creature  4.0    2.0        2.0
# 71            Toxic Iguanar    Red  Creature  1.0    1.0        1.0
# 3          Auriok Sunchaser  White  Creature  2.0    1.0        1.0
# 117         Voldaren Pariah  Black  Creature  5.0    3.0        3.0
# 48           Primoc Escapee   Blue  Creature  7.0    4.0        4.0
# 57         Faerie Miscreant   Blue  Creature  1.0    1.0        1.0
# 33          Synod Artificer   Blue  Creature  3.0    1.0        2.0
# 215  Noyan Dar, Roil Shaper  White  Creature  5.0    4.0        4.0
#             cmc      power  toughness
# count  10.00000  10.000000  10.000000
# mean    3.80000   2.500000   2.300000
# std     2.20101   2.013841   1.337494
# min     1.00000   1.000000   1.000000
# 25%     2.25000   1.000000   1.000000
# 50%     3.50000   1.500000   2.000000
# 75%     5.00000   3.750000   3.750000
# max     7.00000   7.000000   4.000000

# %%
def gower(u, v, R):
    suma = 0
    if (u["colors"] != v["colors"]):
        suma += 1
    if (u["types"] != v["types"]):
        suma += 1
    suma += np.abs(u["cmc"] - v["cmc"])/R['cmc']
    suma += np.abs(u["power"] - v["power"])/R['power']
    suma += np.abs(u["toughness"] - v["toughness"])/R['toughness']
    return suma

dms = np.zeros((mtgs['cmc'].count(), mtgs['cmc'].count()))
Rs = mtgs[['cmc', 'power','toughness']].max() - mtgs[['cmc', 'power','toughness']].min()
x = 0
for iu, u in mtgs.iterrows():
    y = 0
    for iv, v in mtgs.iterrows():
        dms[x][y] = gower(u, v, Rs)
        y += 1
    x += 1
print("\nMatriz redundante de distancias\n", dms)

#Convertir a matriz condensada
cdm = distance.squareform(dms)
print('\nMatriz condensada\n', cdm)

ZM = linkage(cdm, 'single')
print("\nEnlazamientos simples\n", ZM)

plt.figure(figsize=(12, 5))
dendrogram(ZM, labels = mtgs["name"].tolist(), leaf_rotation=75)
plt.show()
# Out:
# Matriz redundante de distancias
#  [[ 0.    3.67  2.    4.    3.83  1.33  1.5   4.    3.33  1.83]
#  [ 3.67  0.    1.67  1.33  0.17  2.33  3.17  1.33  1.33  1.83]
#  [ 2.    1.67  0.    2.    1.83  0.67  2.5   2.    1.33  2.17]
#  [ 4.    1.33  2.    0.    1.17  2.67  3.5   1.    1.67  3.17]
#  [ 3.83  0.17  1.83  1.17  0.    2.5   3.33  1.17  1.5   2.  ]
#  [ 1.33  2.33  0.67  2.67  2.5   0.    1.83  2.67  2.    1.5 ]
#  [ 1.5   3.17  2.5   3.5   3.33  1.83  0.    2.5   1.83  1.33]
#  [ 4.    1.33  2.    1.    1.17  2.67  2.5   0.    0.67  3.17]
#  [ 3.33  1.33  1.33  1.67  1.5   2.    1.83  0.67  0.    2.5 ]
#  [ 1.83  1.83  2.17  3.17  2.    1.5   1.33  3.17  2.5   0.  ]]
#
# Matriz condensada
#  [ 3.67  2.    4.    3.83  1.33  1.5   4.    3.33  1.83  1.67  1.33  0.17
#   2.33  3.17  1.33  1.33  1.83  2.    1.83  0.67  2.5   2.    1.33  2.17
#   1.17  2.67  3.5   1.    1.67  3.17  2.5   3.33  1.17  1.5   2.    1.83
#   2.67  2.    1.5   2.5   1.83  1.33  0.67  3.17  2.5 ]
#
# Enlazamientos simples
#  [[  1.     4.     0.17   2.  ]
#  [  2.     5.     0.67   2.  ]
#  [  7.     8.     0.67   2.  ]
#  [  3.    12.     1.     3.  ]
#  [ 10.    13.     1.17   5.  ]
#  [  0.    11.     1.33   3.  ]
#  [  6.     9.     1.33   2.  ]
#  [ 14.    15.     1.33   8.  ]
#  [ 16.    17.     1.5   10.  ]]

# %%
mtgl = mtg.sample(1000)
dml = np.zeros((mtgl['cmc'].count(), mtgl['cmc'].count()))
Rl = mtgl[['cmc', 'power','toughness']].max() - mtgl[['cmc', 'power','toughness']].min()
x = 0
for iu, u in mtgl.iterrows():
    y = 0
    for iv, v in mtgl.iterrows():
        dml[x][y] = gower(u, v, Rl)
        y += 1
    x += 1

cdml = distance.squareform(dml)

# %%
ZMl = linkage(cdml, 'complete')
plt.figure(figsize=(12, 5))
dendrogram(ZMl, no_labels = True)
plt.show()

# %%
ZM2 = linkage(cdml, 'complete')
plt.figure(figsize=(12, 5))
dendrogram(ZM2, truncate_mode='lastp', p=15, show_leaf_counts=True, leaf_font_size=14.)
plt.show()
